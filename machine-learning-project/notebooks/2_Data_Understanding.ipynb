# %% [markdown]
# # 2. **Data Understanding**

# %%
# %load_ext kedro.ipython
# Out:
# [08/30/25 14:03:27] INFO     Using                                                                  ]8;id=663812;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=658803;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\framework\project\__init__.py#270\270]8;;\
#                              'C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.
#                              venv\Lib\site-packages\kedro\framework\project\rich_logging.yml' as
#                              logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=650965;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=696397;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\ipython\__init__.py#63\63]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=24791;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=280174;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\ipython\__init__.py#65\65]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=472713;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=721331;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\ipython\__init__.py#180\180]8;;\
#                              C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project.
#                              To set a different path, run '%reload_kedro <project_root>'
# [08/30/25 14:03:36] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=321330;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=307410;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro_telemetry\plugin.py#243\243]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [08/30/25 14:03:38] INFO     Kedro project machine_learning_project                                 ]8;id=305133;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=151899;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\ipython\__init__.py#146\146]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=702372;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=712902;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\ipython\__init__.py#147\147]8;;\
#                              'pipelines'

# %%
catalog.keys()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'DataSetFIFA21',
#     'DataSetFIFA20',
#     'DataSetFIFA19',
#     'companies',
#     'reviews',
#     'shuttles',
#     'preprocess_fifa_21',
#     'parameters'
# ]

# %%
catalog.load("DataSetFIFA21")
catalog.load("DataSetFIFA20")
catalog.load("DataSetFIFA19")
# Out:
# [08/30/25 14:03:54] INFO     Loading data from DataSetFIFA21 (CSVDataset)...                   ]8;id=141634;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=30564;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\io\data_catalog.py#1046\1046]8;;\
#                     INFO     Loading data from DataSetFIFA20 (CSVDataset)...                   ]8;id=430438;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=872834;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\io\data_catalog.py#1046\1046]8;;\
#                     INFO     Loading data from DataSetFIFA19 (CSVDataset)...                   ]8;id=850017;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=783514;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\io\data_catalog.py#1046\1046]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        Unnamed: 0      ID           Name  Age  \
# 0               0  176580      L. Suárez   31
# 1               1  194765   A. Griezmann   27
# 2               2  177003      L. Modrić   32
# 3               3  224334       M. Acuña   26
# 4               4  192985   K. De Bruyne   27
# ...           ...     ...            ...  ...
# 17938       17938  233940  M. Brzozowski   19
# 17939       17939  245370  E. Destanoglu   17
# 17940       17940  233215       C. Addai   20
# 17941       17941  246648   O. Battersby   16
# 17942       17942  248182     H. Sveijer   16
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/176/580/19_60.png     Uruguay
# 1      https://cdn.sofifa.com/players/194/765/19_60.png      France
# 2      https://cdn.sofifa.com/players/177/003/19_60.png     Croatia
# 3      https://cdn.sofifa.com/players/224/334/19_60.png   Argentina
# 4      https://cdn.sofifa.com/players/192/985/19_60.png     Belgium
# ...                                                 ...         ...
# 17938  https://cdn.sofifa.com/players/233/940/19_60.png      Poland
# 17939  https://cdn.sofifa.com/players/245/370/19_60.png      Turkey
# 17940  https://cdn.sofifa.com/players/233/215/19_60.png       Ghana
# 17941  https://cdn.sofifa.com/players/246/648/19_60.png     England
# 17942  https://cdn.sofifa.com/players/248/182/19_60.png      Sweden
#
#                                           Flag  Overall  Potential  \
# 0          https://cdn.sofifa.com/flags/uy.png       91         91
# 1          https://cdn.sofifa.com/flags/fr.png       89         89
# 2          https://cdn.sofifa.com/flags/hr.png       91         91
# 3          https://cdn.sofifa.com/flags/ar.png       81         81
# 4          https://cdn.sofifa.com/flags/be.png       91         91
# ...                                        ...      ...        ...
# 17938      https://cdn.sofifa.com/flags/pl.png       49         60
# 17939      https://cdn.sofifa.com/flags/tr.png       50         68
# 17940      https://cdn.sofifa.com/flags/gh.png       51         61
# 17941  https://cdn.sofifa.com/flags/gb-eng.png       50         70
# 17942      https://cdn.sofifa.com/flags/se.png       48         63
#
#                       Club  ... SlidingTackle  GKDiving  GKHandling  \
# 0             FC Barcelona  ...          38.0      27.0        25.0
# 1          Atlético Madrid  ...          48.0      14.0         8.0
# 2              Real Madrid  ...          73.0      13.0         9.0
# 3              Sporting CP  ...          75.0       8.0        14.0
# 4          Manchester City  ...          51.0      15.0        13.0
# ...                    ...  ...           ...       ...         ...
# 17938  Queens Park Rangers  ...          13.0      52.0        52.0
# 17939          Beşiktaş JK  ...          12.0      52.0        52.0
# 17940        Coventry City  ...          13.0      51.0        48.0
# 17941         Grimsby Town  ...          12.0      47.0        51.0
# 17942            IK Sirius  ...          10.0      50.0        49.0
#
#        GKKicking GKPositioning  GKReflexes  Best Position  \
# 0           31.0          33.0        37.0             ST
# 1           14.0          13.0        14.0             LW
# 2            7.0          14.0         9.0             CM
# 3           13.0          13.0        14.0             LM
# 4            5.0          10.0        13.0            CAM
# ...          ...           ...         ...            ...
# 17938       52.0          44.0        51.0             GK
# 17939       50.0          47.0        52.0             GK
# 17940       40.0          54.0        56.0             GK
# 17941       50.0          52.0        53.0             GK
# 17942       48.0          47.0        51.0             GK
#
#        Best Overall Rating Release Clause(£) Year_Joined
# 0                     87.0       164000000.0        2014
# 1                     87.0       145600000.0        2014
# 2                     88.0       137400000.0        2012
# 3                     81.0        38000000.0        2019
# 4                     89.0       172100000.0        2015
# ...                    ...               ...         ...
# 17938                 48.0           84000.0        2015
# 17939                 49.0          126000.0        2018
# 17940                 50.0           98000.0        2016
# 17941                 49.0          138000.0        2018
# 17942                 47.0           94000.0        2019
#
# [17943 rows x 66 columns]

# %%
FIFA21_df = catalog.load("DataSetFIFA21")
FIFA20_df = catalog.load("DataSetFIFA20")
FIFA19_df = catalog.load("DataSetFIFA19")
# Out:
# [08/30/25 14:03:44] INFO     Loading data from DataSetFIFA21 (CSVDataset)...                   ]8;id=270265;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=196848;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\io\data_catalog.py#1046\1046]8;;\
#                     INFO     Loading data from DataSetFIFA20 (CSVDataset)...                   ]8;id=816683;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=567600;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\io\data_catalog.py#1046\1046]8;;\
#                     INFO     Loading data from DataSetFIFA19 (CSVDataset)...                   ]8;id=970566;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=453393;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\machine-learning-project\.venv\Lib\site-packages\kedro\io\data_catalog.py#1046\1046]8;;\

# %% [markdown]
# Importaciones

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
FIFA21_df.head(5)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    Unnamed: 0      ID             Name  Age  \
# 0           0  176580        L. Suárez   33
# 1           1  192985     K. De Bruyne   29
# 2           2  212198  Bruno Fernandes   25
# 3           3  194765     A. Griezmann   29
# 4           4  224334         M. Acuña   28
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/20_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/192/985/20_60.png     Belgium
# 2  https://cdn.sofifa.com/players/212/198/20_60.png    Portugal
# 3  https://cdn.sofifa.com/players/194/765/20_60.png      France
# 4  https://cdn.sofifa.com/players/224/334/20_60.png   Argentina
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       87         87    Atlético Madrid
# 1  https://cdn.sofifa.com/flags/be.png       91         91    Manchester City
# 2  https://cdn.sofifa.com/flags/pt.png       87         90  Manchester United
# 3  https://cdn.sofifa.com/flags/fr.png       87         87       FC Barcelona
# 4  https://cdn.sofifa.com/flags/ar.png       83         83         Sevilla FC
#
#    ... GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes  \
# 0  ...     27.0        25.0       31.0           33.0       37.0
# 1  ...     15.0        13.0        5.0           10.0       13.0
# 2  ...     12.0        14.0       15.0            8.0       14.0
# 3  ...     14.0         8.0       14.0           13.0       14.0
# 4  ...      8.0        14.0       13.0           13.0       14.0
#
#    Best Position  Best Overall Rating  Release Clause(£) DefensiveAwareness  \
# 0             ST                 87.0         64600000.0               57.0
# 1            CAM                 91.0        161000000.0               68.0
# 2            CAM                 88.0        124400000.0               72.0
# 3             ST                 87.0        103500000.0               59.0
# 4             LB                 83.0         46200000.0               79.0
#
#   Year_Joined
# 0        2020
# 1        2015
# 2        2020
# 3        2019
# 4        2020
#
# [5 rows x 67 columns]

# %%
FIFA20_df.head(5)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    Unnamed: 0      ID             Name  Age  \
# 0           0  176580        L. Suárez   32
# 1           1  194765     A. Griezmann   28
# 2           2  212198  Bruno Fernandes   24
# 3           3  192985     K. De Bruyne   28
# 4           4  224334         M. Acuña   27
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/20_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/194/765/20_60.png      France
# 2  https://cdn.sofifa.com/players/212/198/20_60.png    Portugal
# 3  https://cdn.sofifa.com/players/192/985/20_60.png     Belgium
# 4  https://cdn.sofifa.com/players/224/334/20_60.png   Argentina
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       89         89       FC Barcelona
# 1  https://cdn.sofifa.com/flags/fr.png       89         89       FC Barcelona
# 2  https://cdn.sofifa.com/flags/pt.png       86         89  Manchester United
# 3  https://cdn.sofifa.com/flags/be.png       91         91    Manchester City
# 4  https://cdn.sofifa.com/flags/ar.png       82         82        Sporting CP
#
#    ... GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes  \
# 0  ...     27.0        25.0       31.0           33.0       37.0
# 1  ...     14.0         8.0       14.0           13.0       14.0
# 2  ...     12.0        14.0       15.0            8.0       14.0
# 3  ...     15.0        13.0        5.0           10.0       13.0
# 4  ...      8.0        14.0       13.0           13.0       14.0
#
#    Best Position  Best Overall Rating  Release Clause(£) DefensiveAwareness  \
# 0             ST                 89.0        108700000.0               57.0
# 1             CF                 89.0        141500000.0               59.0
# 2            CAM                 87.0        111600000.0               72.0
# 3            CAM                 91.0        166500000.0               68.0
# 4             LB                 82.0         40000000.0               79.0
#
#   Year_Joined
# 0        2014
# 1        2019
# 2        2020
# 3        2015
# 4        2020
#
# [5 rows x 67 columns]

# %%
FIFA19_df.head(5)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    Unnamed: 0      ID          Name  Age  \
# 0           0  176580     L. Suárez   31
# 1           1  194765  A. Griezmann   27
# 2           2  177003     L. Modrić   32
# 3           3  224334      M. Acuña   26
# 4           4  192985  K. De Bruyne   27
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/19_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/194/765/19_60.png      France
# 2  https://cdn.sofifa.com/players/177/003/19_60.png     Croatia
# 3  https://cdn.sofifa.com/players/224/334/19_60.png   Argentina
# 4  https://cdn.sofifa.com/players/192/985/19_60.png     Belgium
#
#                                   Flag  Overall  Potential             Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       91         91     FC Barcelona
# 1  https://cdn.sofifa.com/flags/fr.png       89         89  Atlético Madrid
# 2  https://cdn.sofifa.com/flags/hr.png       91         91      Real Madrid
# 3  https://cdn.sofifa.com/flags/ar.png       81         81      Sporting CP
# 4  https://cdn.sofifa.com/flags/be.png       91         91  Manchester City
#
#    ... SlidingTackle  GKDiving  GKHandling  GKKicking GKPositioning  \
# 0  ...          38.0      27.0        25.0       31.0          33.0
# 1  ...          48.0      14.0         8.0       14.0          13.0
# 2  ...          73.0      13.0         9.0        7.0          14.0
# 3  ...          75.0       8.0        14.0       13.0          13.0
# 4  ...          51.0      15.0        13.0        5.0          10.0
#
#    GKReflexes  Best Position  Best Overall Rating Release Clause(£)  \
# 0        37.0             ST                 87.0       164000000.0
# 1        14.0             LW                 87.0       145600000.0
# 2         9.0             CM                 88.0       137400000.0
# 3        14.0             LM                 81.0        38000000.0
# 4        13.0            CAM                 89.0       172100000.0
#
#   Year_Joined
# 0        2014
# 1        2014
# 2        2012
# 3        2019
# 4        2015
#
# [5 rows x 66 columns]

# %%
FIFA21_df.info()
FIFA21_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17108 entries, 0 to 17107
# Data columns (total 67 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                17108 non-null  int64
#  1   ID                        17108 non-null  int64
#  2   Name                      17108 non-null  object
#  3   Age                       17108 non-null  int64
#  4   Photo                     17108 non-null  object
#  5   Nationality               17108 non-null  object
#  6   Flag                      17108 non-null  object
#  7   Overall                   17108 non-null  int64
#  8   Potential                 17108 non-null  int64
#  9   Club                      17108 non-null  object
#  10  Club Logo                 17108 non-null  object
#  11  Value(£)                  17108 non-null  float64
#  12  Wage(£)                   17108 non-null  float64
#  13  Special                   17108 non-null  int64
#  14  Preferred Foot            17108 non-null  object
#  15  International Reputation  17108 non-null  float64
#  16  Weak Foot                 17108 non-null  float64
#  17  Skill Moves               17108 non-null  float64
#  18  Work Rate                 17108 non-null  object
#  19  Body Type                 17083 non-null  object
#  20  Real Face                 17108 non-null  object
#  21  Position                  17108 non-null  object
#  22  Jersey Number             17108 non-null  float64
#  23  Joined                    17108 non-null  object
#  24  Loaned From               922 non-null    object
#  25  Contract Valid Until      17108 non-null  float64
#  26  Height(cm.)               17108 non-null  float64
#  27  Weight(lbs.)              17108 non-null  int64
#  28  Crossing                  17108 non-null  float64
#  29  Finishing                 17108 non-null  float64
#  30  HeadingAccuracy           17108 non-null  float64
#  31  ShortPassing              17108 non-null  float64
#  32  Volleys                   17108 non-null  float64
#  33  Dribbling                 17108 non-null  float64
#  34  Curve                     17108 non-null  float64
#  35  FKAccuracy                17108 non-null  float64
#  36  LongPassing               17108 non-null  float64
#  37  BallControl               17108 non-null  float64
#  38  Acceleration              17108 non-null  float64
#  39  SprintSpeed               17108 non-null  float64
#  40  Agility                   17108 non-null  float64
#  41  Reactions                 17108 non-null  float64
#  42  Balance                   17108 non-null  float64
#  43  ShotPower                 17108 non-null  float64
#  44  Jumping                   17108 non-null  float64
#  45  Stamina                   17108 non-null  float64
#  46  Strength                  17108 non-null  float64
#  47  LongShots                 17108 non-null  float64
#  48  Aggression                17108 non-null  float64
#  49  Interceptions             17108 non-null  float64
#  50  Positioning               17108 non-null  float64
#  51  Vision                    17108 non-null  float64
#  52  Penalties                 17108 non-null  float64
#  53  Composure                 17108 non-null  float64
#  54  Marking                   942 non-null    float64
#  55  StandingTackle            17108 non-null  float64
#  56  SlidingTackle             17108 non-null  float64
#  57  GKDiving                  17108 non-null  float64
#  58  GKHandling                17108 non-null  float64
#  59  GKKicking                 17108 non-null  float64
#  60  GKPositioning             17108 non-null  float64
#  61  GKReflexes                17108 non-null  float64
#  62  Best Position             17108 non-null  object
#  63  Best Overall Rating       17108 non-null  float64
#  64  Release Clause(£)         17108 non-null  float64
#  65  DefensiveAwareness        17108 non-null  float64
#  66  Year_Joined               17108 non-null  int64
# dtypes: float64(45), int64(8), object(14)
# memory usage: 8.7+ MB
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  17108.000000   17108.000000  17108.000000  17108.000000  17108.000000
# mean    8553.500000  221421.276187     25.053718     66.780161     72.553542
# std     4938.798538   36028.786065      4.915963      7.019069      5.738347
# min        0.000000       2.000000     16.000000     38.000000     46.000000
# 25%     4276.750000  205451.750000     21.000000     62.000000     69.000000
# 50%     8553.500000  230441.000000     24.000000     67.000000     72.000000
# 75%    12830.250000  245402.500000     28.000000     72.000000     76.000000
# max    17107.000000  259105.000000     53.000000     93.000000     95.000000
#
#            Value(£)        Wage(£)       Special  International Reputation  \
# count  1.710800e+04   17108.000000  17108.000000              17108.000000
# mean   2.566142e+06   10458.852584   1625.722995                  1.147533
# std    5.376581e+06   21116.364142    263.503922                  0.455773
# min    0.000000e+00       0.000000    731.000000                  1.000000
# 25%    3.750000e+05    1000.000000   1484.000000                  1.000000
# 50%    8.000000e+05    3000.000000   1653.000000                  1.000000
# 75%    2.400000e+06   10000.000000   1810.000000                  1.000000
# max    1.055000e+08  560000.000000   2316.000000                  5.000000
#
#           Weak Foot  ...  SlidingTackle      GKDiving    GKHandling  \
# count  17108.000000  ...   17108.000000  17108.000000  17108.000000
# mean       2.981938  ...      45.933271     15.660744     15.529928
# std        0.674699  ...      21.189121     16.910205     16.212333
# min        1.000000  ...       6.000000      1.000000      1.000000
# 25%        3.000000  ...      25.000000      8.000000      8.000000
# 50%        3.000000  ...      52.000000     11.000000     11.000000
# 75%        3.000000  ...      64.000000     14.000000     14.000000
# max        5.000000  ...      95.000000     90.000000     92.000000
#
#           GKKicking  GKPositioning    GKReflexes  Best Overall Rating  \
# count  17108.000000   17108.000000  17108.000000         17108.000000
# mean      15.469839      15.550853     15.771510            67.753799
# std       15.977547      16.448905     17.209624             6.773192
# min        1.000000       1.000000      1.000000            42.000000
# 25%        8.000000       8.000000      8.000000            63.000000
# 50%       11.000000      11.000000     11.000000            68.000000
# 75%       14.000000      14.000000     14.000000            72.000000
# max       93.000000      93.000000     90.000000            93.000000
#
#        Release Clause(£)  DefensiveAwareness   Year_Joined
# count       1.710800e+04        17108.000000  17108.000000
# mean        4.725384e+06           47.014475   2018.163257
# std         1.028426e+07           19.589835      2.338500
# min         5.000000e+03            3.000000   1990.000000
# 25%         7.630000e+05           30.000000   2017.000000
# 50%         1.500000e+06           49.000000   2019.000000
# 75%         3.900000e+06           63.000000   2020.000000
# max         2.031000e+08           94.000000   2020.000000
#
# [8 rows x 53 columns]

# %% [markdown]
# Nulos

# %%
FIFA21_df.columns[FIFA21_df.isnull().any()]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['Body Type', 'Loaned From', 'Marking'], dtype='object')

# %%
print("1")
FIFA21_df.isna().sum()
# Out:
# 1
# 1
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Unnamed: 0             0
# ID                     0
# Name                   0
# Age                    0
# Photo                  0
#                       ..
# GKReflexes             0
# Best Position          0
# Best Overall Rating    0
# Release Clause(£)      0
# Year_Joined            0
# Length: 66, dtype: int64

# %%
FIFA20_df.isna().sum()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Unnamed: 0             0
# ID                     0
# Name                   0
# Age                    0
# Photo                  0
#                       ..
# Best Position          0
# Best Overall Rating    0
# Release Clause(£)      0
# DefensiveAwareness     0
# Year_Joined            0
# Length: 67, dtype: int64

# %%
FIFA19_df.isna().sum()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Unnamed: 0             0
# ID                     0
# Name                   0
# Age                    0
# Photo                  0
#                       ..
# GKReflexes             0
# Best Position          0
# Best Overall Rating    0
# Release Clause(£)      0
# Year_Joined            0
# Length: 66, dtype: int64

# %% [markdown]
#  Duplicados

# %%
FIFA21_df[FIFA21_df.duplicated()]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value(£), Wage(£), Special, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Real Face, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height(cm.), Weight(lbs.), Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Best Position, Best Overall Rating, Release Clause(£), DefensiveAwareness, Year_Joined]
# Index: []
#
# [0 rows x 67 columns]

# %%
FIFA20_df[FIFA20_df.duplicated()]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value(£), Wage(£), Special, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Real Face, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height(cm.), Weight(lbs.), Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Best Position, Best Overall Rating, Release Clause(£), DefensiveAwareness, Year_Joined]
# Index: []
#
# [0 rows x 67 columns]

# %%
FIFA19_df[FIFA19_df.duplicated()]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value(£), Wage(£), Special, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Real Face, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height(cm.), Weight(lbs.), Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Best Position, Best Overall Rating, Release Clause(£), Year_Joined]
# Index: []
#
# [0 rows x 66 columns]

# %% [markdown]
# ### Naturaleza de los datos
#
# En el contexto de los datos provenientes del videojuego FIFA, la clasificación de las variables se realiza considerando su representación dentro del juego y su uso potencial en análisis estadísticos o modelos de machine learning.
#
# **Ejemplo Penalties:** Cuando hablamos de **Penalties** no hacemos referencia a cuantos penales efectua o realiza un jugador como si fuera una variable discreta en la cual son numeros enteros, sino, que estamos midiendo una habilidad o en su efectividad en esa acción. Siendo un valor calculado o medido. Para este ejemlo se toma de referencia para las demas variables.
#
# **Tipo de dato:** Como el numero de la camiseta del jugador no se puede calcular, entonces es una variable numerica discreta aun que su formato este en flotante.
#
# Variables que contienen **links o IDs** no seran tomado en cuenta para realizar modelos de machine learning.

# %%
# Variables numericas discretas y continuas

# Numeros enteros: 1,2,3
var_numericas_discretas = ['Age','Overall','Special','Skill Moves',
                          'Jersey Number', 'Year_Joined','Best Overall Rating',
                           'International Reputation','Weak Foot',]


# Decimales o dinero: 1.5, 2.4, $100
#Intercepcion sera continuo porque en FIF se calcula porque se toman muchos valores 
var_numericas_continuas = ['Potential','Value(£)','Wage(£)',
                           'Height(cm.)','Weight(lbs.)','Crossing','Finishing',
                          'HeadingAccuracy','ShortPassing','Volleys','Dribbling',
                          'Curve','FKAccuracy','LongPassing','BallControl','Acceleration',
                          'SprintSpeed','Agility','Reactions','Balance','ShotPower',
                          'Jumping','Stamina','Strength','LongShots','Aggression',
                          'Interceptions','Positioning','Vision','Penalties','Composure',
                          'Marking','StandingTackle','SlidingTackle','GKDiving','GKHandling',
                          'GKKicking','GKPositioning','GKReflexes','Release Clause(£)',
                          'DefensiveAwareness']

# Variables Categoricas ordinales y nominales

#Existe relación de orden en sus categorías.
var_categoricas_ordinales = ['Work Rate']


#N00000 existe relaciónde orden en suscategorías.
var_categoricas_nominales = ['Name','Nationality','Club','Preferred Foot',
                            'Body Type','Real Face','Position','Loaned From',
                            'Best Position']

var_datetime = ['Joined','Contract Valid Until']
var_no_clasificadas = ['Photo','Flag','Club Logo']

print("Clasificacion de las variables")
print("Variables numericas discretas:", var_numericas_discretas)
print("Variables numericas continuas:", var_numericas_continuas)
print("Cantidad:", len(var_numericas_discretas)+len(var_numericas_continuas))
print(f"\nVariables categoricas ordinales:", var_categoricas_ordinales)
print("Variables categoricas nominales:", var_categoricas_nominales)
print("Cantidad:", len(var_categoricas_ordinales)+len(var_categoricas_nominales))
print(f"\nVariables no clasificadas:", var_no_clasificadas)
# Out:
# Clasificacion de las variables
# Variables numericas discretas: ['Age', 'Overall', 'Special', 'Skill Moves', 'Jersey Number', 'Year_Joined', 'Best Overall Rating', 'International Reputation', 'Weak Foot']
# Variables numericas continuas: ['Potential', 'Value(£)', 'Wage(£)', 'Height(cm.)', 'Weight(lbs.)', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause(£)', 'DefensiveAwareness']
# Cantidad: 50
#
# Variables categoricas ordinales: ['Work Rate']
# Variables categoricas nominales: ['Name', 'Nationality', 'Club', 'Preferred Foot', 'Body Type', 'Real Face', 'Position', 'Loaned From', 'Best Position']
# Cantidad: 10
#
# Variables no clasificadas: ['Photo', 'Flag', 'Club Logo']

# %% [markdown]
# ## Analisis estadístico

# %%
# Solo columnas numericas
numeric_df = FIFA21_df.select_dtypes(include=np.number)

# Calculando la correlacion
correlation_matrix = numeric_df.corr()

#  Creando el mapa 
plt.figure(figsize=(30, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numeric Columns')
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 3000x2000 with 2 Axes>
