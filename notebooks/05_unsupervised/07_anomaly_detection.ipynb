# %% [markdown]
# # ***07 — Detección de Anomalías en Jugadores FIFA 22***

# %%
# %load_ext kedro.ipython
# Out:
# [11/27/25 00:36:39] INFO     Using                                                                  ]8;id=846917;file:///usr/local/lib/python3.11/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=345777;file:///usr/local/lib/python3.11/site-packages/kedro/framework/project/__init__.py#270\270]8;;\
#                              '/usr/local/lib/python3.11/site-packages/kedro/framework/project/rich_
#                              logging.yml' as logging configuration.
# [11/27/25 00:36:40] INFO     Registered line magic '%reload_kedro'                                   ]8;id=434903;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=910083;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py#63\63]8;;\
# ...
