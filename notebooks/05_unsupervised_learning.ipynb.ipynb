# %%
# %load_ext kedro.ipython
# Out:
# [11/25/25 03:30:49] INFO     Using                                                                  ]8;id=852174;file:///usr/local/lib/python3.11/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=936287;file:///usr/local/lib/python3.11/site-packages/kedro/framework/project/__init__.py#270\270]8;;\
#                              '/usr/local/lib/python3.11/site-packages/kedro/framework/project/rich_
#                              logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=364011;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=613304;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py#63\63]8;;\
# ...

# %%
catalog.keys()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'DataSetFIFA22',
#     'DataSetFIFA21',
#     'DataSetFIFA20',
#     'preprocess_fifa_22',
#     'preprocess_fifa_21',
#     'preprocess_fifa_20',
#     'FIFA22_processed_con_transformacion2_columns',
#     'FIFA21_processed_con_transformacion2_columnss',
#     'FIFA20_processed_con_transformacion2_columns',
#     'model_input_table',
#     'grid_linear_model',
#     'grid_linear_multiple_model',
#     'grid_svr_model',
#     'grid_decision_tree_model',
#     'grid_randomforest_model',
#     'grid_logistic_model_classification',
#     'grid_knn_model_classification',
#     'grind_svc_cv_model_classification',
#     'grid_decision_tree_model_classification',
#     'grid_random_forest_model_classification',
#     'X_train_regression',
#     'X_test_regression',
#     'y_test_regression',
#     'X_train_class',
#     'X_test_class',
# ...

# %%
catalog.load("model_input_table")
# Out:
# [11/25/25 03:31:17] INFO     Loading data from model_input_table (ParquetDataset)...           ]8;id=184138;file:///usr/local/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=406226;file:///usr/local/lib/python3.11/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                   Name  Age  Nationality  Overall  Potential  \
# 0      Bruno Fernandes   26     Portugal       88         89
# 1          L. Goretzka   26      Germany       87         88
# 2            L. Suárez   34      Uruguay       88         88
# 3             M. Acuña   29    Argentina       84         84
# 4           J. Kimmich   26      Germany       89         90
# ...                ...  ...          ...      ...        ...
# 50521       V. Storsve   17       Norway       50         72
# ...

# %%
df_FIFA = catalog.load("model_input_table")
# Out:
# [11/25/25 03:32:08] INFO     Loading data from model_input_table (ParquetDataset)...           ]8;id=240949;file:///usr/local/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=522382;file:///usr/local/lib/python3.11/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\

# %% [markdown]
# #### **Importaciones**

# %%
# -- Tratamiento de datos --
import numpy as np
import pandas as pd

# -- Gráficos -- 
import seaborn as sns
from matplotlib import style
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import seaborn as sb

# -- Procesado y modelado --
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# -- Importaciónes para modelos de agrupación --


# -- Metricas sugeridas para los modelos --

# Métricas requeridas: Silhouette Score, Davies-Bouldin Index, Calinski-Harabasz Index,  Elbow Method, Dendrogramas

# %% [markdown]
# **Reducción de dimensionalidad**
#
# Implementar al menos 2 técnicas:
# • PCA: Análisis de componentes principales (varianza explicada, loadings, biplot) • t-SNE: Visualización 2D/3D de alta dimensión
# • UMAP: Alternativa moderna a t-SNE
# • SVD/Truncated SVD: Para datos sparse

# %% [markdown]
# **3. Detección de Anomalías (OPCIONAL)**
#
# - Isolation Forest
# - Local Outlier Factor (LOF)
# - One-Class SVM
# - Autoencoders
#
# **4. Reglas de Asociación (OPCIONAL)**
# - Apriori Algorithm
# - FP-Growth
#
# Métricas: support, confidence, lift
