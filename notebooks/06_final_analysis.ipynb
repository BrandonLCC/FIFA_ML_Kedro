# %% [markdown]
# # ***Final analysis***

# %% [markdown]
# ## Primeras etapas

# %% [markdown]
# ## **Modelos supervizados**

# %% [markdown]
# ## **Aprendizaje no supervizado**

# %%
# %load_ext kedro.ipython 
catalog.keys()
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'DataSetFIFA22',
#     'DataSetFIFA21',
#     'DataSetFIFA20',
#     'preprocess_fifa_22',
#     'preprocess_fifa_21',
#     'preprocess_fifa_20',
#     'FIFA22_processed_con_transformacion_columns',
#     'FIFA21_processed_con_transformacion_columns',
#     'FIFA20_processed_con_transformacion_columns',
#     'model_input_table',
#     'X_train_regression',
#     'X_test_regression',
#     'y_test_regression',
#     'X_train_class',
#     'X_test_class',
#     'y_train_class',
#     'y_test_class',
#     'grid_linear_model',
#     'grid_linear_multiple_model',
#     'grid_svr_model',
#     'grid_decision_tree_model',
#     'grid_randomforest_model',
#     'grid_logistic_model_classification',
#     'grid_knn_model_classification',
# ...

# %% [markdown]
# ## **Etapa 1:** analisis y generacion de notebook no supervizados

# %% [markdown]
# Resultados obtenidos

# %% [markdown]
# conclusiones

# %% [markdown]
# ## **Etapa 2:** Generacion de pipelines, componentes y datasets

# %% [markdown]
# ## Componentes generados
#
# - Al realizar la etapa 1 para obtener los componentes necesarios, dentro del proyecto se genera un pipeline para generar xd los componentes.
#
# - Por temas de tiempo y se escoje PCA para la el uso de reduccion de dimencionalidad debido a la calidad del analisis y interpretaciones realizadas. Mientras que umap no se considerara por falta de interpretaciones y conocimiento teorico.

# %%
pca_output = catalog.load("pca_output")
umap_dataset = catalog.load("umap_dataset")

model_input_table_with_pca = catalog.load("model_input_table_with_pca")

model_input_table_with_pca_bcluster =  catalog.load("model_input_PCA_and_best_clusters")
# Out:
# [03/19/26 23:06:31] INFO     Loading data from pca_output (ParquetDataset)...                  ]8;id=513797;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=264777;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py#1046\1046]8;;\
#                     INFO     Loading data from umap_dataset (ParquetDataset)...                ]8;id=330695;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=616;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py#1046\1046]8;;\
# ...

# %%
pca_output
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                 PC1           PC2            PC3         PC4        PC5  \
# 0      2.268247e+08  5.210757e+05  -25633.939379 -810.858724   7.392521
# 1      1.788551e+08  8.972320e+06 -100995.195306 -712.146317  65.775538
# 2      9.511618e+07 -2.370829e+06   19212.371354   85.762760 -56.809527
# 3      7.967980e+07 -2.840922e+06  -51728.196834  360.067640  29.114659
# 4      2.087503e+08  1.041681e+07 -119232.302054 -973.182807  81.794115
# ...             ...           ...            ...         ...        ...
# 44962 -6.211912e+06 -7.356128e+04     965.972029 -838.990514 -13.133335
# 44963 -6.267664e+06 -6.165405e+04    1001.041431 -847.474132 -18.346171
# 44964 -6.260560e+06 -6.533454e+04   -2998.078646 -845.092903  10.211358
# 44965 -6.178003e+06 -7.981709e+04     942.151736 -856.239924   5.397535
# ...

# %%
umap_dataset
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#          UMAP_1     UMAP_2
# 0      5.573100  16.154810
# 1      5.674626  16.066219
# 2      6.761441  15.063475
# 3      7.354212  14.468845
# 4      5.577801  16.150534
# ...         ...        ...
# 44962  0.694308   9.511245
# 44963  1.107728  10.825798
# 44964  1.253667  10.687239
# 44965  0.637696   8.426234
# 44966  1.019657   9.814875
#
# [44967 rows x 2 columns]

# %% [markdown]
# Se suma las columnas del dataframe procesado inicial de los modelos y los componentes, esta es  una opcion ya que en otros casos se puede usar solamente los componentes como entrada de datos para los modelos.

# %%
model_input_table_with_pca
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        Age  Overall  Potential  Special  International Reputation  Weak Foot  \
# 0       26       88         89     2341                       3.0        3.0
# 1       26       87         88     2314                       4.0        4.0
# 2       34       88         88     2307                       5.0        4.0
# 3       29       84         84     2292                       2.0        3.0
# 4       26       89         90     2283                       4.0        4.0
# ...    ...      ...        ...      ...                       ...        ...
# 44962   17       50         72      773                       1.0        2.0
# 44963   19       50         60      764                       1.0        2.0
# 44964   18       50         61      757                       1.0        3.0
# ...

# %% [markdown]
# ## Data +  PCA + clustering
#
# - Segun nuestro evaluador o profesor, nos piden que integremos al menos un clustering como caracteristica y realizar una comparacion de las metricas de los modedelos supervizavos vs modelos supervizados + tecnincas de modelos no supervizados.
#
# ¿Hay una mejora?

# %%
#dataset_for_clustering = catalog.load("dataset_for_clustering")
#dataset_with_best_clusters = catalog.load("dataset_with_best_clusters")
reduccion_clustering_dataset_final = catalog.load("model_input_PCA_and_best_clusters")
# Out:
# [03/19/26 23:06:57] INFO     Loading data from model_input_PCA_and_best_clusters               ]8;id=918363;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=497470;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py#1046\1046]8;;\
#                              (ParquetDataset)...

# %% [markdown]
# Mejor clustering según silhouette: kmeans (score=0.794)

# %%
dataset_with_best_clusters

# %%
dataset_with_best_clusters["clustered_data"].value_counts()

# %%
reduccion_clustering_dataset_final
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        Age  Overall  Potential  Special  International Reputation  Weak Foot  \
# 0       26       88         89     2341                       3.0        3.0
# 1       26       87         88     2314                       4.0        4.0
# 2       34       88         88     2307                       5.0        4.0
# 3       29       84         84     2292                       2.0        3.0
# 4       26       89         90     2283                       4.0        4.0
# ...    ...      ...        ...      ...                       ...        ...
# 44962   17       50         72      773                       1.0        2.0
# 44963   19       50         60      764                       1.0        2.0
# 44964   18       50         61      757                       1.0        3.0
# ...

# %%
analisis inteprretaciones 


# uso
