# %% [markdown]
# # ***Modelo de Regresión logística***

# %%
# %load_ext kedro.ipython
# Out:
# [02/18/26 16:30:52] INFO     Using                                                                  ]8;id=997804;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=157049;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\framework\project\__init__.py#270\270]8;;\
#                              'C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\ke
#                              dro\framework\project\rich_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=886659;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=581809;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py#63\63]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=459802;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=705591;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py#65\65]8;;\
#                     INFO     Resolved project path as: C:\Users\brand\Downloads\Proyecto_ML_Kedro.  ]8;id=931837;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=927728;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py#180\180]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# 2
# [02/18/26 16:31:09] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=298108;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=288587;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro_telemetry\plugin.py#243\243]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [02/18/26 16:31:11] INFO     Kedro project machine_learning_project                                 ]8;id=790937;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=205761;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py#146\146]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=877699;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=561186;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py#147\147]8;;\
#                              'pipelines'
# [02/18/26 16:31:15] INFO     Registered line magic 'run_viz'                                        ]8;id=804398;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=371029;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\ipython\__init__.py#153\153]8;;\

# %%
catalog.keys()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'DataSetFIFA22',
#     'DataSetFIFA21',
#     'DataSetFIFA20',
#     'preprocess_fifa_22',
#     'preprocess_fifa_21',
#     'preprocess_fifa_20',
#     'FIFA22_processed_con_transformacion2_columns',
#     'FIFA21_processed_con_transformacion2_columnss',
#     'FIFA20_processed_con_transformacion2_columns',
#     'model_input_table',
#     'X_train_regression',
#     'X_test_regression',
#     'y_test_regression',
#     'X_train_class',
#     'X_test_class',
#     'y_train_class',
#     'y_test_class',
#     'grid_linear_model',
#     'grid_linear_multiple_model',
#     'grid_svr_model',
#     'grid_decision_tree_model',
#     'grid_randomforest_model',
#     'grid_logistic_model_classification',
#     'grid_knn_model_classification',
#     'grind_svc_cv_model_classification',
#     'grid_decision_tree_model_classification',
#     'grid_random_forest_model_classification',
#     'regression_report_linear_simple',
#     'regression_report_linear_multiple',
#     'regression_report_svr',
#     'regression_report_decision_tree',
#     'regression_report_randomforest',
#     'report_logistic_model_classification',
#     'report_knn_model_classification',
#     'report_grind_svc_cv_model_classification',
#     'report_decision_tree_model_classification',
#     'report_random_forest_model_classification',
#     'clean_dataset',
#     'clustered_dataset',
#     'pca_output',
#     'unsupervised_processed_dataset',
#     'parameters',
#     'params:_modelo_linear_regression',
#     'params:_modelo_linear_multiple_regression',
#     'params:_modelo_svr_regression',
#     'params:_modelo_decision_tree_regression',
#     'params:_modelo_grid_randomforest_regression',
#     'params:model_options_classification',
#     'params:model_options_classification.test_size',
#     'params:model_options_classification.random_state',
#     'params:model_options_classification.stratify',
#     'params:model_options_classification.features',
#     'params:model_options_classification.target',
#     'params:_logistic_param_grid',
#     'params:_logistic_param_grid.logistic__penalty',
#     'params:_logistic_param_grid.logistic__C',
#     'params:_logistic_param_grid.logistic__solver',
#     'params:_logistic_param_grid.logistic__max_iter',
#     'params:_logistic_param_grid.logistic__class_weight',
#     'params:_knn_param_grid',
#     'params:_knn_param_grid.knn__n_neighbors',
#     'params:_knn_param_grid.knn__weights',
#     'params:_knn_param_grid.knn__metric',
#     'params:_knn_param_grid.knn__algorithm',
#     'params:_knn_param_grid.knn__p',
#     'params:_svc_param_grid',
#     'params:_svc_param_grid.svc__C',
#     'params:_svc_param_grid.svc__kernel',
#     'params:_svc_param_grid.svc__gamma',
#     'params:_svc_param_grid.svc__degree',
#     'params:_decision_tree_param_grid',
#     'params:_decision_tree_param_grid.criterion',
#     'params:_decision_tree_param_grid.max_depth',
#     'params:_decision_tree_param_grid.min_samples_split',
#     'params:_decision_tree_param_grid.min_samples_leaf',
#     'params:_decision_tree_param_grid.splitter',
#     'params:_decision_tree_param_grid.class_weight',
#     'params:_random_forest_param_grid',
#     'params:_random_forest_param_grid.n_estimators',
#     'params:_random_forest_param_grid.criterion',
#     'params:_random_forest_param_grid.max_depth',
#     'params:_random_forest_param_grid.min_samples_split',
#     'params:_random_forest_param_grid.min_samples_leaf',
#     'params:_random_forest_param_grid.bootstrap',
#     'params:_random_forest_param_grid.class_weight',
#     'params:_random_forest_param_grid.random_state',
#     'params:dimensionality_reduction',
#     'params:dimensionality_reduction.pca_n_components',
#     'params:dimensionality_reduction.tsne_umap_method',
#     'params:dimensionality_reduction.tsne_umap_n_components',
#     'params:dimensionality_reduction.tsne_umap_random_state',
#     'params:clustering',
#     'params:clustering.kmeans',
#     'params:clustering.kmeans.n_clusters',
#     'params:clustering.kmeans.random_state',
#     'params:clustering.dbscan',
#     'params:clustering.dbscan.eps',
#     'params:clustering.dbscan.min_samples',
#     'params:clustering.hierarchical',
#     'params:clustering.hierarchical.n_clusters',
#     'params:clustering.hierarchical.linkage',
#     'params:anomaly',
#     'params:anomaly.contamination',
#     'params:model_options_regression',
#     'params:model_options_regression.test_size',
#     'params:model_options_regression.random_state',
#     'params:model_options_regression.features',
#     'params:model_options_regression.target',
#     'params:_linear_param_grid',
#     'params:_linear_param_grid.fit_intercept',
#     'params:_linear_param_grid.copy_X',
#     'params:_linear_param_grid.n_jobs',
#     'params:_dt_param_grid',
#     'params:_dt_param_grid.max_depth',
#     'params:_dt_param_grid.min_samples_split',
#     'params:_rf_param_grid',
#     'params:_rf_param_grid.n_estimators',
#     'params:_rf_param_grid.max_depth',
#     'params:_rf_param_grid.min_samples_split',
#     'params:_svr_param_grid',
#     'params:_svr_param_grid.kernel',
#     'params:_svr_param_grid.C',
#     'params:_svr_param_grid.gamma',
#     'params:_modelo_logistic_classification',
#     'params:_modelo_knn_classification',
#     'params:_modelo_xgboost_classification',
#     'params:_modelo_decision_tree_classification',
#     'params:_modelo_random_forest_classification',
#     'params:report_path_logistic',
#     'params:report_path_knn',
#     'params:report_path_svc',
#     'params:report_path_decision_tree',
#     'params:report_path_random_forest'
# ]

# %%
catalog.load("model_input_table")
# Out:
# [02/18/26 16:31:16] INFO     Loading data from model_input_table (ParquetDataset)...           ]8;id=715845;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=476374;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py#1046\1046]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        Age  Overall  Potential  Special  International Reputation  Weak Foot  \
# 0       26       88         89     2341                       3.0        3.0
# 1       26       87         88     2314                       4.0        4.0
# 2       34       88         88     2307                       5.0        4.0
# 3       29       84         84     2292                       2.0        3.0
# 4       26       89         90     2283                       4.0        4.0
# ...    ...      ...        ...      ...                       ...        ...
# 44962   17       50         72      773                       1.0        2.0
# 44963   19       50         60      764                       1.0        2.0
# 44964   18       50         61      757                       1.0        3.0
# 44965   18       51         70      755                       1.0        2.0
# 44966   17       48         63      740                       1.0        2.0
#
#        Skill Moves  Jersey Number  Crossing  Finishing  ...  \
# 0              4.0           18.0      87.0       83.0  ...
# 1              3.0            8.0      75.0       82.0  ...
# 2              3.0            9.0      80.0       93.0  ...
# 3              4.0           19.0      87.0       66.0  ...
# 4              3.0            6.0      91.0       68.0  ...
# ...            ...            ...       ...        ...  ...
# 44962          1.0           41.0      11.0        6.0  ...
# 44963          1.0           39.0      12.0        8.0  ...
# 44964          1.0           30.0      13.0        6.0  ...
# 44965          1.0           78.0      11.0        8.0  ...
# 44966          1.0           35.0      10.0        7.0  ...
#
#        Overall_Class_Bin  Joined_Year  Joined_Month  Joined_Day  Height_cm  \
# 0                      1            0             0           0        179
# 1                      1            0             0           0        189
# 2                      1            0             0           0        182
# 3                      1            0             0           0        172
# 4                      1            0             0           0        177
# ...                  ...          ...           ...         ...        ...
# 44962                  0            0             0           0        185
# 44963                  0            0             0           0        190
# 44964                  0            0             0           0        183
# 44965                  0            0             0           0        190
# 44966                  0            0             0           0        185
#
#        Weight_kg    Value_num  Wage_num  Release Clause_num  Year
# 0      69.000000  107500000.0  250000.0         206900000.0  2022
# 1      82.000000   93000000.0  140000.0         160400000.0  2022
# 2      83.000000   44500000.0  135000.0          91200000.0  2022
# 3      69.000000   37000000.0   45000.0          77700000.0  2022
# 4      75.000000  108000000.0  160000.0         186300000.0  2022
# ...          ...          ...       ...                 ...   ...
# 44962  64.863656      50000.0    5000.0            113000.0  2020
# 44963  81.192968      35000.0    5000.0             58000.0  2020
# 44964  79.832192      35000.0    1000.0             66000.0  2020
# 44965  78.925008      60000.0    5000.0            146000.0  2020
# 44966  76.203456      50000.0    5000.0             94000.0  2020
#
# [44967 rows x 56 columns]

# %%
df_FIFA = catalog.load("model_input_table")
# Out:
#                     INFO     Loading data from model_input_table (ParquetDataset)...           ]8;id=512869;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=339824;file://C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\kedro\io\data_catalog.py#1046\1046]8;;\

# %%
# -- Tratamiento de datos --
import numpy as np
import pandas as pd

# -- Gráficos -- 
import seaborn as sns
from matplotlib import style
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import seaborn as sb

# -- Procesado y modelado --
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# -- Metricas para modelos de clasificación --
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import metrics

#----  Curva ROC y PR ----
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay, average_precision_score

# -- GridSearchCV -- 
from sklearn.model_selection import GridSearchCV

# %%
df_FIFA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44967 entries, 0 to 44966
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       44967 non-null  int64
#  1   Overall                   44967 non-null  int64
#  2   Potential                 44967 non-null  int64
#  3   Special                   44967 non-null  int64
#  4   International Reputation  44967 non-null  float64
#  5   Weak Foot                 44967 non-null  float64
#  6   Skill Moves               44967 non-null  float64
#  7   Jersey Number             44967 non-null  float64
#  8   Crossing                  44967 non-null  float64
#  9   Finishing                 44967 non-null  float64
#  10  HeadingAccuracy           44967 non-null  float64
#  11  ShortPassing              44967 non-null  float64
#  12  Volleys                   44967 non-null  float64
#  13  Dribbling                 44967 non-null  float64
#  14  Curve                     44967 non-null  float64
#  15  FKAccuracy                44967 non-null  float64
#  16  LongPassing               44967 non-null  float64
#  17  BallControl               44967 non-null  float64
#  18  Acceleration              44967 non-null  float64
#  19  SprintSpeed               44967 non-null  float64
#  20  Agility                   44967 non-null  float64
#  21  Reactions                 44967 non-null  float64
#  22  Balance                   44967 non-null  float64
#  23  ShotPower                 44967 non-null  float64
#  24  Jumping                   44967 non-null  float64
#  25  Stamina                   44967 non-null  float64
#  26  Strength                  44967 non-null  float64
#  27  LongShots                 44967 non-null  float64
#  28  Aggression                44967 non-null  float64
#  29  Interceptions             44967 non-null  float64
#  30  Positioning               44967 non-null  float64
#  31  Vision                    44967 non-null  float64
#  32  Penalties                 44967 non-null  float64
#  33  Composure                 44967 non-null  float64
#  34  Marking                   44967 non-null  float64
#  35  StandingTackle            44967 non-null  float64
#  36  SlidingTackle             44967 non-null  float64
#  37  GKDiving                  44967 non-null  float64
#  38  GKHandling                44967 non-null  float64
#  39  GKKicking                 44967 non-null  float64
#  40  GKPositioning             44967 non-null  float64
#  41  GKReflexes                44967 non-null  float64
#  42  Best Overall Rating       44967 non-null  float64
#  43  DefensiveAwareness        44967 non-null  float64
#  44  Offensive_Skills          44967 non-null  float64
#  45  Defensive_Skills          44967 non-null  float64
#  46  Overall_Class_Bin         44967 non-null  int64
#  47  Joined_Year               44967 non-null  Int64
#  48  Joined_Month              44967 non-null  Int64
#  49  Joined_Day                44967 non-null  Int64
#  50  Height_cm                 44967 non-null  int64
#  51  Weight_kg                 44967 non-null  float64
#  52  Value_num                 44967 non-null  float64
#  53  Wage_num                  44967 non-null  float64
#  54  Release Clause_num        44967 non-null  float64
#  55  Year                      44967 non-null  int64
# dtypes: Int64(3), float64(46), int64(7)
# memory usage: 19.3 MB

# %%
df_FIFA.Overall_Class_Bin
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 44962    0
# 44963    0
# 44964    0
# 44965    0
# 44966    0
# Name: Overall_Class_Bin, Length: 44967, dtype: int64

# %% [markdown]
# ### **Desarrollo del Modelo Regresión logística**

# %% [markdown]
# #### **Selección de caracteristicas**

# %%
# en logistic debe estar escalado
X = df_FIFA[["Age","Finishing","Dribbling","International Reputation"]]

 
y = df_FIFA[['Overall_Class_Bin']]

# %% [markdown]
# #### **División de los datos en entrenamiento y prueba**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# Escalado
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# #### **Creación y entrenamiento del modelo KNN**

# %%
modelo = LogisticRegression(class_weight='balanced', max_iter=1000, solver='lbfgs', )
modelo.fit(X_train_scaled, y_train.values.ravel())
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %% [markdown]
# #### **Predicciones sobre el conjunto de prueba**

# %%
y_pred = modelo.predict(X_test)
# Out:
#                     WARNING  C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\skl warnings.py:110
#                              earn\utils\validation.py:2742: UserWarning: X has feature names, but
#                              LogisticRegression was fitted without feature names
#                                warnings.warn(

# %% [markdown]
# ### **Métricas de evaluación**

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[    0 10032]
#  [    0  3459]]
#                     WARNING  C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\skl warnings.py:110
#                              earn\metrics\_classification.py:1731: UndefinedMetricWarning:
#                              Precision is ill-defined and being set to 0.0 in labels with no
#                              predicted samples. Use `zero_division` parameter to control this
#                              behavior.
#                                _warn_prf(average, modifier, f"{metric.capitalize()} is",
#                              result.shape[0])
#                     WARNING  C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\skl warnings.py:110
#                              earn\metrics\_classification.py:1731: UndefinedMetricWarning:
#                              Precision is ill-defined and being set to 0.0 in labels with no
#                              predicted samples. Use `zero_division` parameter to control this
#                              behavior.
#                                _warn_prf(average, modifier, f"{metric.capitalize()} is",
#                              result.shape[0])
#                     WARNING  C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\skl warnings.py:110
#                              earn\metrics\_classification.py:1731: UndefinedMetricWarning:
#                              Precision is ill-defined and being set to 0.0 in labels with no
#                              predicted samples. Use `zero_division` parameter to control this
#                              behavior.
#                                _warn_prf(average, modifier, f"{metric.capitalize()} is",
#                              result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     10032
#            1       0.26      1.00      0.41      3459
#
#     accuracy                           0.26     13491
#    macro avg       0.13      0.50      0.20     13491
# weighted avg       0.07      0.26      0.10     13491

# %%
plt.figure(figsize=(8, 6))
sb.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix for KNN Model")
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 800x600 with 2 Axes>

# %%
#creo que funciona para binarias 
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

# Calculate Sensitivity (Recall)
sensitivity = tp / (tp + fn)

# Calculate Specificity
specificity = tn / (tn + fp)

print(f"Sensitivity (Recall): {sensitivity:.2f}")
print(f"Specificity: {specificity:.2f}")
# Out:
# Sensitivity (Recall): 1.00
# Specificity: 0.00

# %% [markdown]
# ### **Curva Roc**

# %%
# Probabilidades de predicción
y_pred_proba = modelo.predict_proba(X_test)[:,1]

# Calcular la curva ROC y el área bajo la curva
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva Característica de Operación del Receptor (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# [02/18/26 16:31:17] WARNING  C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\skl warnings.py:110
#                              earn\utils\validation.py:2742: UserWarning: X has feature names, but
#                              LogisticRegression was fitted without feature names
#                                warnings.warn(
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %% [markdown]
# #### **Curva PR**

# %%
# Obtener probabilidades del modelo KNN (clase positiva)
y_pred_proba = modelo.predict_proba(X_test)[:, 1]

# Calcular precision, recall y thresholds
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)

# Calcular el área bajo la curva PR
ap_score = average_precision_score(y_test, y_pred_proba)

# Graficar
fig, ax = plt.subplots()
pr_display = PrecisionRecallDisplay(precision=precision, recall=recall)
pr_display.plot(ax=ax)
ax.set_title(f'Precision-Recall Curve for KNN Model (AP = {ap_score:.2f})')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#                     WARNING  C:\Users\brand\Downloads\Proyecto_ML_Kedro\.venv\Lib\site-packages\skl warnings.py:110
#                              earn\utils\validation.py:2742: UserWarning: X has feature names, but
#                              LogisticRegression was fitted without feature names
#                                warnings.warn(
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %% [markdown]
# ### **GridsearchCV**

# %%
param_grid = {
    "penalty": ["l2"],
    "C": [0.1, 1, 10],
    "solver": ["lbfgs"],
    "max_iter": [500],
    "class_weight": [None]
}

# Crear el objeto LogisticRegression
logistic_regression = LogisticRegression(class_weight='balanced')

# Crear el objeto GridSearchCV
grid_search = GridSearchCV(estimator=logistic_regression, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Ajustar GridSearchCV a los datos de entrenamiento escalados
grid_search.fit(X_train_scaled, y_train.values.ravel())

# Mostrar los mejores parámetros encontrados
print("Mejores parámetros encontrados por GridSearchCV:")
print(grid_search.best_params_)

# Mostrar el mejor puntaje (accuracy) obtenido
print("Mejor score (accuracy) en el conjunto de validación:")
print(grid_search.best_score_)

# Evaluar el mejor modelo encontrado en el conjunto de prueba
best_model = grid_search.best_estimator_
y_pred_best = best_model.predict(X_test_scaled)

print("\nMétricas de clasificación del mejor modelo en el conjunto de prueba:")
print(classification_report(y_test, y_pred_best))
print("Accuracy en el conjunto de prueba:", accuracy_score(y_test, y_pred_best))

# Matriz de confusión del mejor modelo
cm_best = confusion_matrix(y_test, y_pred_best)
print("\nMatriz de Confusión del mejor modelo:\n", cm_best)

# Graficar la matriz de confusión del mejor modelo
plt.figure(figsize=(8, 6))
sns.heatmap(cm_best, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicho Negativo', 'Predicho Positivo'], yticklabels=['Real Negativo', 'Real Positivo'])
plt.xlabel('Predicción')
plt.ylabel('Valor Real')
plt.title('Matriz de Confusión - Mejor Modelo de Regresión Logística (GridSearchCV)')
plt.show()

# Curva ROC y PR del mejor modelo
y_scores_best = best_model.predict_proba(X_test_scaled)[:, 1]
roc_auc_best = roc_auc_score(y_test, y_scores_best)
print(f"\nROC AUC Score del mejor modelo: {roc_auc_best:.3f}")

fpr_best, tpr_best, thresholds_best = roc_curve(y_test, y_scores_best)
# Out:
# Mejores parámetros encontrados por GridSearchCV:
# {'C': 1, 'class_weight': None, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# Mejor score (accuracy) en el conjunto de validación:
# 0.815256057277059
#
# Métricas de clasificación del mejor modelo en el conjunto de prueba:
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.89     10032
#            1       0.80      0.36      0.50      3459
#
#     accuracy                           0.81     13491
#    macro avg       0.81      0.66      0.69     13491
# weighted avg       0.81      0.81      0.79     13491
#
# Accuracy en el conjunto de prueba: 0.8129864354013787
#
# Matriz de Confusión del mejor modelo:
#  [[9730  302]
#  [2221 1238]]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 800x600 with 2 Axes>
# ROC AUC Score del mejor modelo: 0.822

# %% [markdown]
# #### **Sensitivity y Specificity modelo con GridSearchCV**

# %%
cm_best = confusion_matrix(y_test, y_pred)
tn_best, fp_best, fn_best, tp_best = cm_best.ravel()

sensitivity_best = tp_best / (tp_best + fn_best)
specificity_best = tn_best / (tn_best + fp_best)

print("\nMétricas del mejor modelo de GridSearchCV:")
print(f"Sensitivity: {sensitivity_best:.4f}")
print(f"Specificity: {specificity_best:.4f}")
# Out:
# Métricas del mejor modelo de GridSearchCV:
# Sensitivity: 1.0000
# Specificity: 0.0000

# %% [markdown]
# ### **Curva Roc y Curva PR de GridSearchCV**

# %%
# Probabilidades para la clase positiva (usar datos escalados)
y_pred_proba = best_model.predict_proba(X_test_scaled)[:, 1]

# === CURVA ROC ===
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC del Mejor Modelo (Logistic Regression)')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

print("-")

# === CURVA PRECISIÓN-RECALL ===
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred_proba)
average_precision = average_precision_score(y_test, y_pred_proba)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='blue', lw=2, label='Curva PR (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Curva Precision-Recall del Mejor Modelo (Logistic Regression)')
plt.legend(loc="lower left")
plt.grid(True)
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 800x600 with 1 Axes>
# -
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 800x600 with 1 Axes>
