# %%
# %load_ext kedro.ipython
# Out:
# [11/25/25 17:15:01] INFO     Using                                                                  ]8;id=583712;file:///usr/local/lib/python3.11/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=646035;file:///usr/local/lib/python3.11/site-packages/kedro/framework/project/__init__.py#270\270]8;;\
#                              '/usr/local/lib/python3.11/site-packages/kedro/framework/project/rich_
#                              logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=469447;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=81098;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py#63\63]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=604520;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=983317;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py#65\65]8;;\
#                     INFO     Resolved project path as: /app.                                        ]8;id=273359;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=640885;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py#180\180]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [11/25/25 17:15:10] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=553978;file:///usr/local/lib/python3.11/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=852675;file:///usr/local/lib/python3.11/site-packages/kedro_telemetry/plugin.py#243\243]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [11/25/25 17:15:11] INFO     Kedro project machine_learning_project                                 ]8;id=823819;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=844127;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py#146\146]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=533651;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=213267;file:///usr/local/lib/python3.11/site-packages/kedro/ipython/__init__.py#147\147]8;;\
#                              'pipelines'
# [11/25/25 17:15:12] WARNING  Failed to load kedro_viz.launchers.jupyter commands from                  ]8;id=467454;file:///usr/local/lib/python3.11/site-packages/kedro/framework/cli/utils.py\utils.py]8;;\:]8;id=632825;file:///usr/local/lib/python3.11/site-packages/kedro/framework/cli/utils.py#346\346]8;;\
#                              EntryPoint(name='line_magic',
#                              value='kedro_viz.launchers.jupyter:run_viz', group='kedro.line_magic').
#                              Full exception: email-validator version >= 2.0 required, run pip install
#                              -U email-validator

# %%
catalog.keys()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'DataSetFIFA22',
#     'DataSetFIFA21',
#     'DataSetFIFA20',
#     'preprocess_fifa_22',
#     'preprocess_fifa_21',
#     'preprocess_fifa_20',
#     'FIFA22_processed_con_transformacion2_columns',
#     'FIFA21_processed_con_transformacion2_columnss',
#     'FIFA20_processed_con_transformacion2_columns',
#     'model_input_table',
#     'grid_linear_model',
#     'grid_linear_multiple_model',
#     'grid_svr_model',
#     'grid_decision_tree_model',
#     'grid_randomforest_model',
#     'grid_logistic_model_classification',
#     'grid_knn_model_classification',
#     'grind_svc_cv_model_classification',
#     'grid_decision_tree_model_classification',
#     'grid_random_forest_model_classification',
#     'X_train_regression',
#     'X_test_regression',
#     'y_test_regression',
#     'X_train_class',
#     'X_test_class',
#     'y_train_class',
#     'y_test_class',
#     'regression_report_linear_simple',
#     'regression_report_linear_multiple',
#     'regression_report_svr',
#     'regression_report_decision_tree',
#     'regression_report_randomforest',
#     'report_logistic_model_classification',
#     'report_knn_model_classification',
#     'report_grind_svc_cv_model_classification',
#     'report_decision_tree_model_classification',
#     'report_random_forest_model_classification',
#     'parameters',
#     'params:_modelo_logistic_classification',
#     'params:_modelo_knn_classification',
#     'params:_modelo_xgboost_classification',
#     'params:_modelo_decision_tree_classification',
#     'params:_modelo_random_forest_classification',
#     'params:report_path_logistic',
#     'params:report_path_knn',
#     'params:report_path_svc',
#     'params:report_path_decision_tree',
#     'params:report_path_random_forest',
#     'params:_modelo_linear_regression',
#     'params:_modelo_linear_multiple_regression',
#     'params:_modelo_svr_regression',
#     'params:_modelo_decision_tree_regression',
#     'params:_modelo_grid_randomforest_regression',
#     'params:model_options',
#     'params:model_options.test_size',
#     'params:model_options.random_state',
#     'params:model_options.features',
#     'params:model_options.target',
#     'params:_linear_param_grid',
#     'params:_linear_param_grid.fit_intercept',
#     'params:_linear_param_grid.positive',
#     'params:_dt_param_grid',
#     'params:_dt_param_grid.max_depth',
#     'params:_dt_param_grid.min_samples_split',
#     'params:_rf_param_grid',
#     'params:_rf_param_grid.n_estimators',
#     'params:_rf_param_grid.max_depth',
#     'params:_rf_param_grid.min_samples_split',
#     'params:_svr_param_grid',
#     'params:_svr_param_grid.kernel',
#     'params:_svr_param_grid.C',
#     'params:_svr_param_grid.gamma',
#     'params:model_options_classification',
#     'params:model_options_classification.test_size',
#     'params:model_options_classification.random_state',
#     'params:model_options_classification.stratify',
#     'params:features',
#     'params:target',
#     'params:_logistic_param_grid',
#     'params:_logistic_param_grid.logistic__penalty',
#     'params:_logistic_param_grid.logistic__C',
#     'params:_logistic_param_grid.logistic__solver',
#     'params:_logistic_param_grid.logistic__max_iter',
#     'params:_logistic_param_grid.logistic__class_weight',
#     'params:_knn_param_grid',
#     'params:_knn_param_grid.knn__n_neighbors',
#     'params:_knn_param_grid.knn__weights',
#     'params:_knn_param_grid.knn__metric',
#     'params:_knn_param_grid.knn__algorithm',
#     'params:_knn_param_grid.knn__p',
#     'params:_svc_param_grid',
#     'params:_svc_param_grid.svc__C',
#     'params:_svc_param_grid.svc__kernel',
#     'params:_svc_param_grid.svc__gamma',
#     'params:_decision_tree_param_grid',
#     'params:_decision_tree_param_grid.criterion',
#     'params:_decision_tree_param_grid.max_depth',
#     'params:_decision_tree_param_grid.min_samples_split',
#     'params:_decision_tree_param_grid.min_samples_leaf',
#     'params:_decision_tree_param_grid.splitter',
#     'params:_decision_tree_param_grid.class_weight',
#     'params:_random_forest_param_grid',
#     'params:_random_forest_param_grid.n_estimators',
#     'params:_random_forest_param_grid.criterion',
#     'params:_random_forest_param_grid.max_depth',
#     'params:_random_forest_param_grid.min_samples_split',
#     'params:_random_forest_param_grid.min_samples_leaf',
#     'params:_random_forest_param_grid.bootstrap',
#     'params:_random_forest_param_grid.class_weight',
#     'params:_random_forest_param_grid.random_state'
# ]

# %%
catalog.load("model_input_table")
# Out:
# [11/25/25 17:15:13] INFO     Loading data from model_input_table (ParquetDataset)...           ]8;id=93783;file:///usr/local/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=241909;file:///usr/local/lib/python3.11/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                   Name  Age  Nationality  Overall  Potential  \
# 0      Bruno Fernandes   26     Portugal       88         89
# 1          L. Goretzka   26      Germany       87         88
# 2            L. Suárez   34      Uruguay       88         88
# 3             M. Acuña   29    Argentina       84         84
# 4           J. Kimmich   26      Germany       89         90
# ...                ...  ...          ...      ...        ...
# 50521       V. Storsve   17       Norway       50         72
# 50522        B. Sinzig   19  Switzerland       50         60
# 50523    18 N. Krucker   18  Switzerland       50         61
# 50524    18 A. Viscovo   18        Italy       51         70
# 50525       H. Sveijer   17       Sweden       48         63
#
#                      Club  Special Preferred Foot  International Reputation  \
# 0       Manchester United     2341          Right                       3.0
# 1       FC Bayern München     2314          Right                       4.0
# 2      Atlético de Madrid     2307          Right                       5.0
# 3              Sevilla FC     2292           Left                       2.0
# 4       FC Bayern München     2283          Right                       4.0
# ...                   ...      ...            ...                       ...
# 50521       Lillestrøm SK      773          Right                       1.0
# 50522     Neuchâtel Xamax      764          Right                       1.0
# 50523       FC St. Gallen      757          Right                       1.0
# 50524             Crotone      755          Right                       1.0
# 50525           IK Sirius      740          Right                       1.0
#
#        Weak Foot  ...  Height_cm  Weight_kg    Value_num  Wage_num  \
# 0            3.0  ...        179  69.000000  107500000.0  250000.0
# 1            4.0  ...        189  82.000000   93000000.0  140000.0
# 2            4.0  ...        182  83.000000   44500000.0  135000.0
# 3            3.0  ...        172  69.000000   37000000.0   45000.0
# 4            4.0  ...        177  75.000000  108000000.0  160000.0
# ...          ...  ...        ...        ...          ...       ...
# 50521        2.0  ...        185  64.863656      50000.0    5000.0
# 50522        2.0  ...        190  81.192968      35000.0    5000.0
# 50523        3.0  ...        183  79.832192      35000.0    1000.0
# 50524        2.0  ...        190  78.925008      60000.0    5000.0
# 50525        2.0  ...        185  76.203456      50000.0    5000.0
#
#        Release Clause_num Best_Position_Grouped_FW  Best_Position_Grouped_GK  \
# 0             206900000.0                    False                     False
# 1             160400000.0                    False                     False
# 2              91200000.0                     True                     False
# 3              77700000.0                    False                     False
# 4             186300000.0                    False                     False
# ...                   ...                      ...                       ...
# 50521            113000.0                    False                      True
# 50522             58000.0                    False                      True
# 50523             66000.0                    False                      True
# 50524            146000.0                    False                      True
# 50525             94000.0                    False                      True
#
#        Best_Position_Grouped_MF  Overall_Class_Encoded  Year
# 0                          True                      0  2022
# 1                          True                      0  2022
# 2                         False                      0  2022
# 3                         False                      0  2022
# 4                          True                      0  2022
# ...                         ...                    ...   ...
# 50521                     False                      1  2020
# 50522                     False                      1  2020
# 50523                     False                      1  2020
# 50524                     False                      1  2020
# 50525                     False                      1  2020
#
# [50526 rows x 70 columns]

# %%
df_FIFA = catalog.load("model_input_table")
# Out:
#                     INFO     Loading data from model_input_table (ParquetDataset)...           ]8;id=991866;file:///usr/local/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=564755;file:///usr/local/lib/python3.11/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\

# %% [markdown]
# #### **Importaciones**

# %%
# -- Tratamiento de datos --
import numpy as np
import pandas as pd

# -- Gráficos -- 
import seaborn as sns
from matplotlib import style
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import seaborn as sb

# -- Procesado y modelado --
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# -- Importaciónes para modelos de agrupación --


# -- Metricas sugeridas para los modelos --

# Métricas requeridas: Silhouette Score, Davies-Bouldin Index, Calinski-Harabasz Index,  Elbow Method, Dendrogramas

# %% [markdown]
# **Introduccion teorica** - (Benefició propio)
#
# Hasta ahora, tan sólo hemos explorado algoritmos y técnicas de Aprendizaje Automático supervisado para desarrollar modelos en los que los datos tenían etiquetas previamente conocidas.
#
# En otras palabras, nuestros datos tenían algunas variables objetivo con valores específicos que utilizamos para entrenar nuestros modelos.
#
# Sin embargo, cuando se trata de problemas del mundo real, la mayoría de las veces, los datos no vienen con etiquetas predefinidas: tenemos las características de entrada X, pero no tenemos las etiquetas Y. Estos son los modelos de Aprendizaje Automático No Supervisado.
#
# El Aprendizaje no Supervisado pretende descubrir patrones previamente desconocidos en los datos, pero la mayoría de las veces estos patrones son aproximaciones deficientes de lo que el Aprendizaje Supervisado puede lograr.
#
# Además, dado que no sabe cuáles deberían ser los resultados, no hay forma de determinar cuán precisos son, lo que hace que el Aprendizaje Supervisado sea más aplicable a los problemas del mundo real.
#
# El mejor momento para utilizar el Aprendizaje no Supervisado es cuando no se dispone de datos sobre los resultados deseados

# %% [markdown]
# - **Los algoritmos de Aprendizaje no Supervisado manejan datos sin entrenamiento previo**
#
# - **Los algoritmos no supervisados funcionan con datos no etiquetados. Su propósito es la exploración**

# %% [markdown]
# **Algunos ejemplos de  aplicación de este tipo de modelos**
#
# - La **agrupación** en clústeres divide automáticamente el conjunto de datos en grupos en función de sus similitudes.
#
# - La **detección de anomalías** puede descubrir puntos de datos inusuales en su conjunto de datos. Es útil para encontrar transacciones fraudulentas.
#
# - La **minería de asociaciones** Se refiere a descubrir patrones y relaciones comunes entre los distintos atributos de un conjunto de datos.
#
# - Los **modelos de variables latente**s se utilizan ampliamente para el preprocesamiento de datos. Cómo reducir el número de características en un conjunto de datos o descomponer el conjunto de datos en múltiples componentes.
#
# **Tecnicas de Unsupervised Learning en Machine learning**
# ```
#  Unsupervised Learning
#         |
# data without label (datos sin etiqueta)
#         |
#         - -> Clustering
#         |
#         | 1. K-means
#         | 2. K-median
#         | 3. Hierarchical clustering
#         | 4. Expectation Maximization
#         |
#         - -> Association Analysis
#         |
#         | 1. APRIORI
#         | 2. Eclat
#         | 3. FP-Growth
#         |
#         - -> Dimensionality Reduction
#
#           1. Feature Extraction
#              - Principal Component Analysis
#           2. Feature Selection
#              - Wrapper, filter y Embedded Method
#
# ```
#
# CLUSTERING
#
# En términos básicos, el objetivo de la agrupación es encontrar diferentes grupos dentro de los elementos de los datos.
#
# ANÁLISIS DE ASOCIACIÓN
#
# Se refiere a descubrir patrones y relaciones comunes entre los distintos atributos de un conjunto de datos.
#
# La atención se centra en qué atributos o características del conjunto de datos aparecen juntos con frecuencia y cuáles no.
#
#
# REDUCCIÓN DE LA DIMENSIONALIDAD
#
# Se refiere a reducir características de los datos conservando la información más importante. Es decir, transformar el conjunto de datos a uno de menor dimensión.

# %% [markdown]
# Antes de realizar los algoritmos, necesitamos tener una interpretación clara definiendo los objetivos.
#
# **Objetivos**
#
# ¿Qué queremos obtener del dataset?
#
# Agrupar clientes/jugadores/observaciones con características similares.
#
# Detectar anomalías (valores fuera de lo normal).
#
# Reducir dimensionalidad para visualizar o mejorar modelos posteriores.
#
# Identificar patrones escondidos.

# %% [markdown]
# ## **Unsupervised Learning**

# %% [markdown]
# **Analizar los datos (EDA) sin etiquetas**

# %% [markdown]
# ### **1. Clustering**
# Implementación y comparación de 3 algoritmos (seleccionar al menos 3)
#
# - K-Means: Clustering particional basado en centroides  (este)
# - DBSCAN: Clustering basado en densidad (este)
# - Hierarchical Clustering: Clustering jerárquico (este)
# - Gaussian Mixture Models: Clustering probabilístico (penultimo)
# - OPTICS: Alternativa a DBSCAN para densidad variable (ultimo)
#
# **Métricas utilizadas:** Silhouette Score, Davies-Bouldin Index, Calinski-Harabasz Index,  Elbow Method, Dendrogramas
#
# Con esta informacion ya puedes empezar

# %% [markdown]
# ### **2. Reducción de dimensionalidad**
#
# Implementar al menos 2 técnicas:
#
# - PCA: Análisis de componentes principales (varianza explicada, loadings, biplot)
# - t-SNE: Visualización 2D/3D de alta dimensión
# - UMAP: Alternativa moderna a t-SNE
# - SVD/Truncated SVD: Para datos sparse

# %% [markdown]
# ### **3. Detección de Anomalías (OPCIONAL)**
#
# - Isolation Forest
# - Local Outlier Factor (LOF)
# - One-Class SVM
# - Autoencoders
#
# ### **4. Reglas de Asociación (OPCIONAL)**
# - Apriori Algorithm
# - FP-Growth
#
# Métricas: support, confidence, lift
